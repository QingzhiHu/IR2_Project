# %%
import pandas as pd

# %%
data = pd.read_excel('mrr.xlsx', index_col=None)  
data
# Out:
#         knrm  conv-knrm       tk1       tk2       tk3      bert
# 0   0.106262   0.084015  0.213386  0.215858  0.211491  0.287332
# 1   0.116821   0.126860  0.218762  0.222782  0.221407  0.302174
# 2   0.123700   0.161212  0.223726  0.225806  0.223754  0.312984
# 3   0.125333   0.173587  0.223492  0.225011  0.225541  0.322875
# 4   0.129956   0.179766  0.227390  0.229804  0.228768  0.322186
# 5   0.134648   0.182847  0.229344  0.232644  0.232343  0.331207
# 6   0.137284   0.189689  0.229696  0.232730  0.233683  0.326136
# 7   0.141858   0.198004  0.231231  0.235140  0.236572  0.328991
# 8   0.143016   0.200590  0.230897  0.233279  0.235988  0.337132
# 9   0.146438   0.202749  0.234072  0.236996  0.237069  0.335019
# 10  0.149262   0.207478  0.235889  0.239984  0.242071  0.336650

# %%
data.plot()
# Out:
# <AxesSubplot:>

# %%
loss = pd.read_excel('loss.xlsx', index_col=None)  
loss = loss.rename(columns={"After_Batch": "Batch", "knrm": "KNRM", "conv-knrm":"CONV-KNRM","tk1":"TK_1_layer", "tk2":"TK_2_layer", "tk3":"TK_3_layer", "bert":"BERT"})
loss
# Out:
#      Batch      KNRM  CONV-KNRM  TK_1_layer  TK_2_layer  TK_3_layer      BERT
# 0      100  0.700849   0.697317    0.838558    0.798839    0.765396  0.702832
# 1      200  0.692749   0.688424    0.710841    0.696120    0.686703  0.642538
# 2      300  0.690830   0.686095    0.569878    0.572207    0.580580  0.472660
# 3      400  0.688444   0.680459    0.467981    0.455532    0.465104  0.209689
# 4      500  0.687034   0.677076    0.430678    0.418820    0.419736  0.193736
# ..     ...       ...        ...         ...         ...         ...       ...
# 457  45800  0.287421   0.137096    0.114838    0.105449    0.115000  0.050544
# 458  45900  0.280177   0.166333    0.139226    0.145050    0.128344  0.047918
# 459  46000  0.279295   0.142831    0.143075    0.128495    0.124902  0.060711
# 460  46100  0.268643   0.168397    0.139718    0.126656    0.117514  0.050051
# 461  46200  0.294724   0.178997    0.140828    0.139637    0.144223  0.055967
#
# [462 rows x 7 columns]

# %%
loss.plot(x="Batch",ylabel="losses")
# Out:
# <AxesSubplot:xlabel='Batch', ylabel='losses'>

# %%
msmarco_doc = pd.read_csv(r'C:\Users\qhuca\Downloads\IR2_final\IR2_Project\training_data\validation\robustness04.eval.tsv', sep='\t', header=None)  
msmarco_doc
# Out:
#           0              1                                                  2  \
# 0       301    FBIS3-10082  international organized crime identify organiz...
# 1       360    FBIS3-10082  drug legalization benefits what are the benefi...
# 2       301    FBIS3-10169  international organized crime identify organiz...
# 3       349    FBIS3-10169  metabolism document will discuss the chemical ...
# 4       357    FBIS3-10169  territorial waters dispute identify documents ...
# ...     ...            ...                                                ...
# 311405  700  LA121490-0082  gasoline tax us what are the arguments for and...
# 311406  700  LA121789-0120  gasoline tax us what are the arguments for and...
# 311407  700  LA121990-0122  gasoline tax us what are the arguments for and...
# 311408  700  LA122189-0128  gasoline tax us what are the arguments for and...
# 311409  700  LA122889-0096  gasoline tax us what are the arguments for and...
#
# ...
