# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
data1 = pd.read_csv("queries.doctrain.tsv", sep='\t', header=None)
data1.rename({0: 'qid', 1: 'query'}, axis=1, inplace=True)
data1
# Out:
#             qid                                              query
# 0       1185869  )what was the immediate impact of the success ...
# 1       1185868  _________ justice is designed to repair the ha...
# 2       1183785                                     elegxo meaning
# 3        645590                     what does physical medicine do
# 4        186154         feeding rice cereal how many times per day
# ...         ...                                                ...
# 367008    19285                         anterolisthesis definition
# 367009   558837                             what are fishing flies
# 367010   559149           what are fsh levels during perimenopause
# 367011   706678                                    what is a yowie
# 367012   405466                           is carbonic acid soluble
#
# [367013 rows x 2 columns]

# %%
data2 = pd.read_csv("msmarco-doctrain-top100", sep=' ', header=None)
data2.rename({0: 'qid', 1: 'Q0', 2:'docid', 3:'rank', 4:'score', 5:'runstring'}, axis=1, inplace=True)
data2
# Out:
#               qid  Q0     docid  rank    score             runstring
# 0         1185869  Q0    D59221     1 -4.80433  IndriQueryLikelihood
# 1         1185869  Q0    D59220     2 -4.92127  IndriQueryLikelihood
# 2         1185869  Q0  D2192591     3 -5.05215  IndriQueryLikelihood
# 3         1185869  Q0  D2777518     4 -5.05486  IndriQueryLikelihood
# 4         1185869  Q0  D2371978     5 -5.07048  IndriQueryLikelihood
# ...           ...  ..       ...   ...      ...                   ...
# 36701111   748176  Q0  D2519846    96 -6.27750  IndriQueryLikelihood
# 36701112   748176  Q0  D1660014    97 -6.27775  IndriQueryLikelihood
# 36701113   748176  Q0  D3395520    98 -6.27988  IndriQueryLikelihood
# 36701114   748176  Q0  D2519845    99 -6.28317  IndriQueryLikelihood
# 36701115   748176  Q0  D3083754   100 -6.28339  IndriQueryLikelihood
#
# [36701116 rows x 6 columns]

# %%
temp = pd.merge(data1, data2, on='qid')[["qid","query","docid","rank"]]
temp
# Out:
#               qid                                              query  \
# 0         1185869  )what was the immediate impact of the success ...
# 1         1185869  )what was the immediate impact of the success ...
# 2         1185869  )what was the immediate impact of the success ...
# 3         1185869  )what was the immediate impact of the success ...
# 4         1185869  )what was the immediate impact of the success ...
# ...           ...                                                ...
# 36701111   405466                           is carbonic acid soluble
# 36701112   405466                           is carbonic acid soluble
# 36701113   405466                           is carbonic acid soluble
# 36701114   405466                           is carbonic acid soluble
# 36701115   405466                           is carbonic acid soluble
#
#              docid  rank
# 0           D59221     1
# 1           D59220     2
# 2         D2192591     3
# 3         D2777518     4
# 4         D2371978     5
# ...            ...   ...
# 36701111  D1022930    96
# 36701112  D2143398    97
# 36701113  D2263321    98
# 36701114  D2097415    99
# 36701115  D1741236   100
#
# [36701116 rows x 4 columns]

# %%
df = temp[temp["rank"]==1]
df = df.drop(columns=['rank'])
df
# Out:
#               qid                                              query     docid
# 0         1185869  )what was the immediate impact of the success ...    D59221
# 100       1185868  _________ justice is designed to repair the ha...    D59232
# 200       1183785                                     elegxo meaning   D576811
# 300        645590                     what does physical medicine do   D877577
# 400        186154         feeding rice cereal how many times per day   D114788
# ...           ...                                                ...       ...
# 36700616    19285                         anterolisthesis definition   D576752
# 36700716   558837                             what are fishing flies  D1342947
# 36700816   559149           what are fsh levels during perimenopause   D957409
# 36700916   706678                                    what is a yowie   D576779
# 36701016   405466                           is carbonic acid soluble   D612613
#
# [367012 rows x 3 columns]

# %%
docid_list = df[["docid"]].values.tolist()
docid_list = [item for sublist in docid_list for item in sublist]
docid_list
# Out:
# ['D59221',
#  'D59232',
#  'D576811',
#  'D877577',
#  'D114788',
#  'D618043',
#  'D576852',
#  'D881339',
#  'D576869',
#  'D899441',
#  'D1175633',
#  'D922494',
#  'D576914',
#  'D968250',
#  'D1350737',
#  'D1349235',
#  'D1814859',
#  'D576944',
#  'D1923598',
#  'D576960',
#  'D2938163',
#  'D1209176',
#  'D114799',
#  'D576988',
#  'D576994',
#  'D2507072',
#  'D516081',
#  'D1779325',
#  'D577014',
#  'D2998861',
#  'D1342966',
#  'D577024',
#  'D2699211',
#  'D577051',
#  'D2557598',
#  'D484863',
#  'D1091565',
#  'D3548676',
#  'D28504',
#  'D476008',
#  'D12957',
#  'D2655234',
#  'D3323093',
#  'D216558',
#  'D577143',
#  'D577149',
#  'D3462406',
#  'D577155',
#  'D577162',
#  'D577177',
#  'D878611',
#  'D577200',
#  'D76939',
#  'D114832',
#  'D3035405',
#  'D577239',
#  'D613810',
#  'D1806805',
#  'D1375802',
#  'D216558',
#  'D223127',
#  'D1484479',
#  'D577285',
#  'D15657',
#  'D3114404',
#  'D3111187',
#  'D43977',
#  'D577369',
#  'D577378',
#  'D1653187',
#  'D2766696',
#  'D3233728',
#  'D1833356',
#  'D982425',
#  'D577435',
#  'D2403536',
#  'D1749167',
#  'D2904338',
#  'D112500',
#  'D577487',
#  'D577507',
#  'D105998',
#  'D1251467',
#  'D2704198',
#  'D2360633',
#  'D577529',
#  'D3393795',
#  'D499548',
#  'D2213357',
#  'D114865',
#  'D577575',
#  'D435106',
#  'D3040303',
#  'D3024106',
#  'D3422468',
#  'D15212',
#  'D1075392',
#  'D2891056',
#  'D2130497',
#  'D2228650',
#  'D577672',
#  'D577686',
#  'D577690',
#  'D216558',
#  'D1178049',
#  'D577699',
#  'D732194',
#  'D577704',
#  'D2808263',
#  'D2401814',
#  'D2306088',
#  'D3194365',
#  'D2369083',
#  'D577791',
#  'D577799',
#  'D577806',
#  'D54421',
#  'D2913720',
#  'D3047766',
#  'D1857466',
#  'D104040',
#  'D577861',
#  'D2495052',
#  'D1695627',
#  'D259061',
#  'D577908',
#  'D1326988',
#  'D2335659',
#  'D577924',
#  'D1548624',
#  'D435956',
#  'D577947',
#  'D649893',
#  'D1041514',
#  'D2482809',
#  'D902652',
#  'D578003',
#  'D658247',
#  'D2786466',
#  'D2033502',
#  'D2482809',
#  'D3278109',
#  'D578030',
#  'D578047',
#  'D669746',
#  'D578071',
#  'D1438669',
#  'D114939',
#  'D578125',
#  'D753725',
#  'D666220',
#  'D3420508',
#  'D578161',
#  'D578183',
#  'D83261',
#  'D1161808',
#  'D114950',
#  'D578214',
#  'D578250',
#  'D2554382',
#  'D649185',
#  'D221636',
#  'D2562968',
#  'D2271551',
#  'D578328',
#  'D216558',
#  'D2322908',
#  'D459422',
#  'D2573814',
#  'D3387232',
#  'D68432',
#  'D578431',
#  'D1629292',
#  'D3281173',
#  'D819205',
#  'D905575',
#  'D2561852',
#  'D2686943',
#  'D1688809',
#  'D556204',
#  'D3261512',
#  'D704841',
#  'D351184',
#  'D460449',
#  'D3519370',
#  'D578588',
#  'D578592',
#  'D68313',
#  'D73381',
#  'D2549881',
#  'D563735',
#  'D578611',
#  'D1014679',
#  'D769698',
#  'D2106691',
#  'D578648',
#  'D852272',
#  'D183304',
#  'D714947',
#  'D578675',
#  'D64926',
#  'D2741781',
#  'D1888914',
#  'D578719',
#  'D578730',
#  'D578749',
#  'D1181635',
#  'D1327162',
#  'D216558',
#  'D157961',
#  'D1220644',
#  'D115027',
#  'D855352',
#  'D578851',
#  'D139410',
#  'D2800861',
#  'D1662613',
#  'D2708933',
#  'D2299096',
#  'D789054',
#  'D3552684',
#  'D2394625',
#  'D578931',
#  'D336710',
#  'D578961',
#  'D265713',
#  'D1657904',
#  'D3388232',
#  'D3009087',
#  'D1700844',
#  'D1244507',
#  'D626409',
#  'D11419',
#  'D163128',
#  'D101122',
#  'D624972',
#  'D2670307',
#  'D2832308',
#  'D2531121',
#  'D625216',
#  'D3303594',
#  'D545161',
#  'D579205',
#  'D1015046',
#  'D579247',
#  'D277779',
#  'D195217',
#  'D909162',
#  'D579270',
#  'D579277',
#  'D299329',
#  'D2920679',
#  'D352487',
#  'D1804038',
#  'D1915521',
#  'D366341',
#  'D70845',
#  'D312261',
#  'D579330',
#  'D3318837',
#  'D443155',
#  'D1697128',
#  'D579351',
#  'D3333354',
#  'D2956438',
#  'D1183071',
#  'D500092',
#  'D1811502',
#  'D2963338',
#  'D140330',
#  'D2640684',
#  'D2679218',
#  'D3102981',
#  'D2620680',
#  'D2114241',
#  'D579483',
#  'D579488',
#  'D579509',
#  'D2686103',
#  'D262330',
#  'D1110284',
#  'D1970489',
#  'D3426415',
#  'D2205894',
#  'D2764831',
#  'D1548882',
#  'D281912',
#  'D307654',
#  'D1901925',
#  'D1645665',
#  'D39867',
#  'D2501942',
#  'D1295801',
#  'D579643',
#  'D579651',
#  'D579653',
#  'D1367264',
#  'D579689',
#  'D579698',
#  'D2725585',
#  'D579711',
#  'D1117760',
#  'D961097',
#  'D579742',
#  'D115130',
#  'D579750',
#  'D2742163',
#  'D579777',
#  'D579797',
#  'D2433450',
#  'D1449005',
#  'D2660186',
#  'D176498',
#  'D1747104',
#  'D3259666',
#  'D579869',
#  'D322298',
#  'D110692',
#  'D579897',
#  'D115146',
#  'D1142697',
#  'D2734765',
#  'D2653106',
#  'D1601829',
#  'D763642',
#  'D579939',
#  'D3345007',
#  'D83204',
#  'D2753129',
#  'D372673',
#  'D1982981',
#  'D1825528',
#  'D1119681',
#  'D579996',
#  'D580011',
#  'D580016',
#  'D3038726',
#  'D612357',
#  'D3089743',
#  'D687626',
#  'D1423424',
#  'D580062',
#  'D580066',
#  'D2547756',
#  'D580636',
#  'D750503',
#  'D1277890',
#  'D2245866',
#  'D580111',
#  'D2035133',
#  'D3457461',
#  'D580130',
#  'D2613995',
#  'D580153',
#  'D2394753',
#  'D596329',
#  'D126904',
#  'D2379649',
#  'D447715',
#  'D3344086',
#  'D3401866',
#  'D115192',
#  'D3167620',
#  'D580219',
#  'D3457461',
#  'D216558',
#  'D3190943',
#  'D3516080',
#  'D1313273',
#  'D2172545',
#  'D2678708',
#  'D580297',
#  'D580302',
#  'D454997',
#  'D840843',
#  'D1995601',
#  'D2062775',
#  'D124218',
#  'D580358',
#  'D1075533',
#  'D178252',
#  'D2936721',
#  'D580422',
#  'D580428',
#  'D580431',
#  'D1102157',
#  'D216558',
#  'D1998356',
#  'D580491',
#  'D275696',
#  'D115220',
#  'D580520',
#  'D945622',
#  'D216558',
#  'D3305072',
#  'D1980028',
#  'D115228',
#  'D580574',
#  'D580577',
#  'D3366529',
#  'D2264155',
#  'D1711956',
#  'D115236',
#  'D955936',
#  'D580636',
#  'D334910',
#  'D64954',
#  'D216558',
#  'D580693',
#  'D115245',
#  'D582079',
#  'D2011663',
#  'D1000322',
#  'D1498756',
#  'D2075855',
#  'D115251',
#  'D120174',
#  'D443451',
#  'D580809',
#  'D1680190',
#  'D115260',
#  'D580818',
#  'D2521742',
#  'D2242148',
#  'D561408',
#  'D2307506',
#  'D952708',
#  'D209133',
#  'D1013394',
#  'D601199',
#  'D2794590',
#  'D580911',
#  'D1601829',
#  'D126261',
#  'D580969',
#  'D78760',
#  'D2988093',
#  'D344018',
#  'D581002',
#  'D352578',
#  'D581003',
#  'D581008',
#  'D2004290',
#  'D1509655',
#  'D377775',
#  'D805211',
#  'D2833303',
#  'D581069',
#  'D581103',
#  'D281280',
#  'D581131',
#  'D2139689',
#  'D581142',
#  'D581144',
#  'D581156',
#  'D142558',
#  'D2640684',
#  'D64961',
#  'D2481010',
#  'D581170',
#  'D768570',
#  'D581184',
#  'D1437491',
#  'D1823783',
#  'D374174',
#  'D581224',
#  'D353210',
#  'D2006294',
#  'D2375533',
#  'D823803',
#  'D955109',
#  'D1311343',
#  'D3175852',
#  'D581288',
#  'D581292',
#  'D116308',
#  'D581325',
#  'D778045',
#  'D1181110',
#  'D1521890',
#  'D3297391',
#  'D1739281',
#  'D115328',
#  'D330975',
#  'D571419',
#  'D446816',
#  'D985002',
#  'D3032447',
#  'D581437',
#  'D581443',
#  'D639520',
#  'D1806805',
#  'D2312966',
#  'D791110',
#  'D581498',
#  'D581504',
#  'D561112',
#  'D827666',
#  'D1120583',
#  'D581550',
#  'D115349',
#  'D724931',
#  'D126881',
#  'D2389823',
#  'D59800',
#  'D278553',
#  'D543602',
#  'D3249634',
#  'D2184759',
#  'D216558',
#  'D604923',
#  'D1521973',
#  'D581705',
#  'D1359749',
#  'D581738',
#  'D2892421',
#  'D1450615',
#  'D115376',
#  'D2500934',
#  'D818326',
#  'D3259113',
#  'D581859',
#  'D581868',
#  'D600853',
#  'D665040',
#  'D3502044',
#  'D466117',
#  'D1022700',
#  'D1632300',
#  'D561313',
#  'D215592',
#  'D2573400',
#  'D1285718',
#  'D416943',
#  'D1006436',
#  'D109809',
#  'D478484',
#  'D3020074',
#  'D1145425',
#  'D582043',
#  'D582046',
#  'D2415417',
#  'D577701',
#  'D2118921',
#  'D582079',
#  'D582084',
#  'D582093',
#  'D53456',
#  'D231630',
#  'D1154927',
#  'D3518350',
#  'D115423',
#  'D582145',
#  'D2354958',
#  'D58275',
#  'D1629547',
#  'D1275476',
#  'D582192',
#  'D2630625',
#  'D2349194',
#  'D582221',
#  'D582228',
#  'D553214',
#  'D1967566',
#  'D322609',
#  'D85823',
#  'D582258',
#  'D776389',
#  'D778045',
#  'D704099',
#  'D2456776',
#  'D2844687',
#  'D1923952',
#  'D582323',
#  'D1783155',
#  'D1685325',
#  'D1715706',
#  'D1832851',
#  'D754415',
#  'D582385',
#  'D582393',
#  'D930583',
#  'D1693199',
#  'D582401',
#  'D582409',
#  'D3404448',
#  'D571955',
#  'D3303127',
#  'D216558',
#  'D582462',
#  'D168387',
#  'D3036476',
#  'D2056061',
#  'D582483',
#  'D2708252',
#  'D2397950',
#  'D3159552',
#  'D2730069',
#  'D3543587',
#  'D1258968',
#  'D2976510',
#  'D3040303',
#  'D2074488',
#  'D582587',
#  'D582601',
#  'D582605',
#  'D2953954',
#  'D3447243',
#  'D582629',
#  'D1616546',
#  'D582638',
#  'D582657',
#  'D3056916',
#  'D2028545',
#  'D1435546',
#  'D582712',
#  'D808973',
#  'D582731',
#  'D1052362',
#  'D626951',
#  'D3255408',
#  'D582747',
#  'D582754',
#  'D1077255',
#  'D3286083',
#  'D1357562',
#  'D2677611',
#  'D582803',
#  'D237301',
#  'D416057',
#  'D511632',
#  'D582822',
#  'D3332593',
#  'D582847',
#  'D2464594',
#  'D780575',
#  'D582869',
#  'D582883',
#  'D11992',
#  'D1218886',
#  'D292447',
#  'D1478713',
#  'D970564',
#  'D582919',
#  'D985109',
#  'D325472',
#  'D70084',
#  'D2379618',
#  'D2078695',
#  'D582986',
#  'D752751',
#  'D583013',
#  'D583015',
#  'D583029',
#  'D2552811',
#  'D583050',
#  'D2728007',
#  'D3420766',
#  'D583079',
#  'D3214793',
#  'D115509',
#  'D1402264',
#  'D583122',
#  'D1002786',
#  'D583143',
#  'D452924',
#  'D2451139',
#  'D115523',
#  'D504369',
#  'D712104',
#  'D1340125',
#  'D583193',
#  'D312629',
#  'D557796',
#  'D2039420',
#  'D782018',
#  'D1155020',
#  'D583273',
#  'D583275',
#  'D583285',
#  'D583288',
#  'D1135681',
#  'D583315',
#  'D1737076',
#  'D2595333',
#  'D583363',
#  'D1413965',
#  'D115540',
#  'D1361893',
#  'D413993',
#  'D292296',
#  'D2697274',
#  'D583413',
#  'D1921335',
#  'D115548',
#  'D48149',
#  'D583440',
#  'D631425',
#  'D2347772',
#  'D583460',
#  'D1409462',
#  'D1342761',
#  'D3311229',
#  'D1366958',
#  'D3158320',
#  'D216558',
#  'D269661',
#  'D583544',
#  'D690619',
#  'D64984',
#  'D583600',
#  'D1601162',
#  'D1913512',
#  'D2540697',
#  'D519560',
#  'D221275',
#  'D1358628',
#  'D1176697',
#  'D583704',
#  'D583726',
#  'D2539670',
#  'D325207',
#  'D2899681',
#  'D750292',
#  'D2821759',
#  'D430903',
#  'D583811',
#  'D3111791',
#  'D1421802',
#  'D583828',
#  'D2761636',
#  'D1986429',
#  'D583846',
#  'D216558',
#  'D486448',
#  'D935731',
#  'D2754781',
#  'D2943350',
#  'D583900',
#  'D2216719',
#  'D583914',
#  'D925491',
#  'D3248191',
#  'D1942989',
#  'D765128',
#  'D3396254',
#  'D2471672',
#  'D992278',
#  'D641838',
#  'D3058591',
#  'D115609',
#  'D1814533',
#  'D2018736',
#  'D639879',
#  'D64992',
#  'D3190260',
#  'D839063',
#  'D1223597',
#  'D766181',
#  'D1613595',
#  'D584097',
#  'D844975',
#  'D584105',
#  'D3044398',
#  'D226024',
#  'D584136',
#  'D322902',
#  'D3468714',
#  'D584159',
#  'D1864740',
#  'D584196',
#  'D584198',
#  'D3022509',
#  'D115622',
#  'D853514',
#  'D224943',
#  'D2792393',
#  'D49437',
#  'D2066748',
#  'D584266',
#  'D583836',
#  'D578250',
#  'D629021',
#  'D584314',
#  'D2437523',
#  'D2543560',
#  'D137376',
#  'D3534066',
#  'D1181948',
#  'D584367',
#  'D179695',
#  'D3334423',
#  'D385160',
#  'D1208087',
#  'D2813742',
#  'D584421',
#  'D584433',
#  'D2833661',
#  'D2197129',
#  'D1933649',
#  'D216558',
#  'D584503',
#  'D2811863',
#  'D425211',
#  'D1845067',
#  'D2678338',
#  'D2294417',
#  'D3285490',
#  'D1337879',
#  'D1558093',
#  'D425076',
#  'D2498089',
#  'D331344',
#  'D1123177',
#  'D2438026',
#  'D584626',
#  'D584645',
#  'D44585',
#  'D584680',
#  'D136560',
#  'D584691',
#  'D1073605',
#  'D198881',
#  'D584718',
#  'D287915',
#  'D2137093',
#  'D1928744',
#  'D584760',
#  'D2182051',
#  'D388542',
#  'D198359',
#  'D584783',
#  'D2700016',
#  'D3091750',
#  'D660163',
#  'D3207927',
#  'D1414085',
#  'D584842',
#  'D584846',
#  'D584857',
#  'D1735527',
#  'D1440312',
#  'D3364975',
#  'D584886',
#  'D372825',
#  'D1715174',
#  'D3144337',
#  'D835209',
#  'D2221412',
#  'D1108160',
#  'D2494426',
#  'D10964',
#  'D216558',
#  'D822667',
#  'D200450',
#  'D3545021',
#  'D538123',
#  'D1396606',
#  'D585024',
#  'D585035',
#  'D585039',
#  'D585043',
#  'D963401',
#  'D115745',
#  'D3343431',
#  'D261264',
#  'D585085',
#  'D2556856',
#  'D1866338',
#  'D1010047',
#  'D1736560',
#  'D585131',
#  'D585164',
#  'D585185',
#  'D585192',
#  'D595074',
#  'D2405893',
#  'D705366',
#  'D585241',
#  'D585245',
#  'D585253',
#  'D585271',
#  'D1708407',
#  'D585293',
#  'D1870667',
#  'D1521973',
#  'D585323',
#  'D2745630',
#  'D779077',
#  'D2726928',
#  'D573879',
#  'D988756',
#  'D585385',
#  'D271607',
#  'D3234332',
#  'D115788',
#  'D585441',
#  'D585447',
#  'D452737',
#  'D392904',
#  'D3541631',
#  'D585481',
#  'D2654700',
#  'D571614',
#  'D585518',
#  'D208480',
#  'D617522',
#  'D585536',
#  'D585554',
#  'D115796',
#  'D112187',
#  'D373686',
#  'D3421246',
#  'D1300246',
#  'D585625',
#  'D2020393',
#  'D3268072',
#  'D585652',
#  'D364846',
#  'D585662',
#  'D112881',
#  'D1566993',
#  'D216558',
#  'D1942969',
#  'D115820',
#  'D229624',
#  'D252225',
#  'D585736',
#  'D528987',
#  'D1855696',
#  'D3545334',
#  'D216558',
#  'D1331837',
#  'D3026210',
#  'D3168295',
#  'D1791041',
#  'D43596',
#  'D1204887',
#  'D676782',
#  'D109000',
#  'D585851',
#  'D2613079',
#  'D585869',
#  'D1199749',
#  'D2185060',
#  'D2393354',
#  'D585892',
#  'D585900',
#  'D3064838',
#  'D2299031',
#  'D585920',
#  'D115852',
#  'D805257',
#  'D437983',
#  'D1019428',
#  'D65022',
#  'D1003187',
#  'D1799014',
#  'D1776555',
#  'D1124223',
#  'D93165',
#  'D586030',
#  'D586041',
#  'D2867624',
#  'D586062',
#  'D80472',
#  'D586084',
#  'D704670',
#  'D586099',
#  'D939273',
#  'D586133',
#  'D425094',
#  'D1754059',
#  'D586165',
#  'D1408660',
#  'D586184',
#  'D3535344',
#  'D702389',
#  'D586212',
#  'D652828',
#  'D2121742',
#  'D462991',
#  'D586265',
#  'D586281',
#  'D1831827',
#  'D586301',
#  'D586315',
#  'D586318',
#  'D1269715',
#  'D956332',
#  'D115890',
#  'D586372',
#  'D586396',
#  'D317820',
#  'D586418',
#  'D3109305',
#  'D739563',
#  'D586438',
#  'D586442',
#  'D586463',
#  ...]

# %%
from tqdm import tqdm
# Opening file
with open('msmarco_doc_merge.tsv',"r",encoding="utf8") as in_file:
    with open('msmarco_doc_merge_processed_train.txt',"w",encoding="utf8") as out_file:
        for line in tqdm(in_file):
            ls = line.split("\t")
            if ls[0] in docid_list:
                out_file.write(ls[0]+"\t"+ls[1]+" "+ls[2])
# Out:
# 13718it [04:39, 49.02it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-626085f3ff54> in <module>
#       3 with open('msmarco_doc_merge.tsv',"r",encoding="utf8") as in_file:
#       4     with open('msmarco_doc_merge_processed_train.txt',"w",encoding="utf8") as out_file:
# ----> 5         for line in tqdm(in_file):
#       6             ls = line.split("\t")
#       7             if ls[0] in docid_list:
#
# ~\anaconda3\lib\site-packages\tqdm\std.py in __iter__(self)
#    1167                 # Update and possibly print the progressbar.
#    1168                 # Note: does not call self.update(1) for speed optimisation.
# -> 1169                 n += 1
#    1170                 # check counter first to avoid calls to time()
#    1171                 if n - last_print_n >= self.miniters:
#
# KeyboardInterrupt:

# %%
data3 = pd.read_csv('msmarco_doc_merge_processed_train.txt', sep='\t', header=None)
data3
# Out:
#              0                                                  1
# 0     D1683153  How many people died in the Atomic Bombing? Ml...
# 1     D1594061  What is the difference between technology infu...
# 2     D2730421  When does Fahrenheit 451 take place? "Answers....
# 3     D2791432  Why was The Battle of Midway an important even...
# 4      D955411  Shared Flashcard Set Shared Flashcard Set Deta...
# ...        ...                                                ...
# 5051   D323009  Publication 521 - Main Content "Publication 52...
# 5052  D2347969  "Why Did Pope Urban Call The First Crusade In ...
# 5053  D3016113  6.3: Visible-Light Detectors and Instruments S...
# 5054  D1162930  How to Go Through Airport Security Smoothly "R...
# 5055   D653894  Frequently Asked Questions â Provisional Drive...
#
# [5056 rows x 2 columns]

# %%
data3.rename({0: 'docid', 1: 'document'}, axis=1, inplace=True)
data3
# Out:
#          docid                                           document
# 0     D1683153  How many people died in the Atomic Bombing? Ml...
# 1     D1594061  What is the difference between technology infu...
# 2     D2730421  When does Fahrenheit 451 take place? "Answers....
# 3     D2791432  Why was The Battle of Midway an important even...
# 4      D955411  Shared Flashcard Set Shared Flashcard Set Deta...
# ...        ...                                                ...
# 5051   D323009  Publication 521 - Main Content "Publication 52...
# 5052  D2347969  "Why Did Pope Urban Call The First Crusade In ...
# 5053  D3016113  6.3: Visible-Light Detectors and Instruments S...
# 5054  D1162930  How to Go Through Airport Security Smoothly "R...
# 5055   D653894  Frequently Asked Questions â Provisional Drive...
#
# [5056 rows x 2 columns]

# %%
df_final = pd.merge(df, data3, on='docid')[["qid","docid","query","document"]]
df_final
# Out:
#           qid     docid                                              query  \
# 0      174249  D3126539  does xpress bet charge to deposit money in you...
# 1      320792  D1138810               how much is a cost to run disneyland
# 2     1090270   D342531                               botulinum definition
# 3     1101279  D2858049  do physicians pay for insurance from their sal...
# 4      201376   D353952                        here there be dragons comic
# ...       ...       ...                                                ...
# 5188   147073    D54853  difference between discrete and process manufa...
# 5189   243761   D907861                 how long did abraham lincoln serve
# 5190   162662    D56193       does adult acne rosacea give you blepharitis
# 5191   247194   D448044                       how long do you bake muffins
# 5192   195199   D620497                                     glioma meaning
#
#                                                document
# 0     BetYetu- Registration, How to Bet, Bonus, Jack...
# 1     . Q Entrance fee to euro disney, paris? How mu...
# 2     Medical Dictionary "Migraine Headache Main Art...
# 3     2012-2015 Concierge Physician Salary Report 20...
# 4     Comic Book Newsstand Editions: Understanding T...
# ...                                                 ...
# 5188  Difference Between Discrete and Process Manufa...
# 5189  How many terms did Abraham Lincoln serve as Pr...
# 5190  About Dry Eyes, Blepharitis and Ocular Rosacea...
# 5191  How long do you bake muffins for? Answers.com ...
# 5192  Medical Terminology: Suffixes Medical Terminol...
#
# [5193 rows x 4 columns]

# %%
df_final.to_csv('msmarco_doc_eval.tsv', header=None, index=None, sep='\t', mode='a')

# %%
# Out:
#               0                                                  1         2  \
# 0       1185869  )what was the immediate impact of the success ...    D59219
# 1       1185868  _________ justice is designed to repair the ha...    D59235
# 2       1183785                                     elegxo meaning   D576811
# 3        645590                     what does physical medicine do   D576840
# 4        186154         feeding rice cereal how many times per day   D114789
# ...         ...                                                ...       ...
# 364337   630000                 what does a producer of a movie do  D1159275
# 364338   613681                      what county is thurmont md in  D1362705
# 364339   401258                         is a webcam a input device  D1362710
# 364340   622430                         what do cats drink and eat  D1362716
# 364341   748176                               what is fmla, stress  D1362719
#
#                                                         3  \
# 0                http://www.pitt.edu/~sdb14/atombomb.html
# 1       https://en.wikipedia.org/wiki/Restorative_justice
# 2       http://gracebibleny.org/the_ministry_of_the_ho...
# 3       https://www.spine-health.com/treatment/spine-s...
# 4       http://pediatriccareassociates.com/FeedingGuid...
# ...                                                   ...
# 364337  http://entertainment.howstuffworks.com/movie-p...
# 364338  https://www.mapquest.com/us/md/thurmont-282029656
# 364339  https://www.techopedia.com/definition/5333/webcam
# 364340  https://answers.yahoo.com/question/index?qid=2...
# 364341  http://work.chron.com/stress-leave-employer-ri...
#
#                                                         4  \
# 0                                            Introduction
# 1                                     Restorative justice
# 2                         The Ministry of the Holy Spirit
# 3                                  What Is a Physiatrist?
# 4                   FEEDING GUIDELINES AGES 4 TO 6 MONTHS
# ...                                                   ...
# 364337                           How Movie Producers Work
# 364338                                           Thurmont
# 364339                                             Webcam
# 364340  What do cats eat and drink other than cat food...
# 364341                     Stress Leave & Employer Rights
#
#                                                         5         6  \
# 0       The Manhattan Project Introduction Importance ...  D2104433
# 1       From Wikipedia, the free encyclopedianavigatio...  D3069826
# 2       John, Sermons 2001The Ministry of the Holy Spi...  D1183294
# 3       Looking for a Physiatrist? Find a Physiatrist ...  D3043062
# 4       FEEDING GUIDELINES AGES 4 TO 6 MONTHSSTARTING ...  D2791236
# ...                                                   ...       ...
# 364337  Responsibilities of a Movie Producer Prev NEXT...  D2911824
# 364338  Thurmont Thurmont, MDFavorite Share More Nearb...  D1105590
# 364339  Webcam Definition - What does Webcammean? A we...  D1591775
# 364340  Pets Cats What do cats eat and drink other tha...  D1096655
# 364341  Related Articles1How to Write a Letter for a V...   D771128
#
#                                                         7  \
# 0       https://www.osti.gov/opennet/manhattan-project...
# 1       http://www.bexar.org/506/Programs-Services-Spe...
# 2       https://forrestgump.wordpress.com/2007/08/25/s...
# 3       http://www.answeranimal.com/How_long_for_cat_w...
# 4       http://www.babycenter.ca/a1040403/how-to-intro...
# ...                                                   ...
# 364337  http://vigilantcitizen.com/moviesandtv/starry-...
# 364338  https://www.expedia.com/Gettysburg-Hotels.d605...
# 364339  https://quizlet.com/56453257/cgs2060-ch-7-9-fl...
# 364340  https://www.vetinfo.com/vets/answers/how-long-...
# 364341  https://hr.nih.gov/help/faq/benefits/leave/fam...
#
#                                                         8  \
# 0                                                       .
# 1                  Programs Services and Specialty Courts
# 2                                       Swear in Albanian
# 3                                                       .
# 4                How to introduce solid food to your baby
# ...                                                   ...
# 364337  âStarry Eyesâ : A Movie About the Occult Holly...
# 364338                              Gettysburg Hotels $41
# 364339                                     CGS2060 ch 7-9
# 364340           Vet Directory: Find a local vet near you
# 364341     What is a serious health condition under FMLA?
#
#                                                         9
# 0       THE TRINITY TEST (Trinity Test Site, July 16, ...
# 1       Programs Services and Specialty Courts Interme...
# 2       Swear in Albanian Posted on August 25, 2007 | ...
# 3       Q How long for cat worm medicine to work? How ...
# 4       How to introduce solid food to your baby Appro...
# ...                                                   ...
# 364337  Movies and TV“Starry Eyes” : A Movie About the...
# 364338  Hide Where to stay in Gettysburg Hotel Class1 ...
# 364339  145 terms msaunders24CGS2060 ch 7-9Learn Flash...
# 364340  How long after having puppies does a female do...
# 364341  What is a serious health condition under FMLA?...
#
# [364342 rows x 10 columns]
